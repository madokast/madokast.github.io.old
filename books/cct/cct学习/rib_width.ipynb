# %%
import rib宽度计算器
# Out:
# dicct in 0.8985216622118397
# dicct in 5.399625114499295
# dicct out 0.8168020479258908
# dicct out 5.364204035887382
# agcct out 2.0623270513728613
# agcct out 8.884181946500487
# agcct out 9.000328120086547
# agcct out 1.9765180366816306
